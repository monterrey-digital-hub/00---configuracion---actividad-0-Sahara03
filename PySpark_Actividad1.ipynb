# %% [markdown]
# PySpark Actividad 1:
#
# Corre la siguiente celda sin ningun problema, recordando la configuración que vimos

# %%
import pyspark as ps
import random

spark = ps.sql.SparkSession.builder \
        .appName("rdd test") \
        .getOrCreate()

random.seed(1)

def sample(p):
    x, y = random.random(), random.random()
    return 1 if x*x + y*y < 1 else 0

count = spark.sparkContext.parallelize(range(0, 10000000)).map(sample) \
        .reduce(lambda a, b: a + b)

print("Pi is (very) roughly {}".format(4.0 * count / 10000000))
# Out:
# Pi is (very) roughly 3.1414944

# %% [markdown]
# El resultado debe ser

# %% [markdown]
# ![2021-12-20 17_59_12-PySpark_Actividad1.ipynb - Colaboratory.png](data:image/png;base64,...)

# %% [markdown]
# ¿Qué hace la función sample(p)?

# %% [markdown]
# ### Escribe tu respuesta aquí ☕
